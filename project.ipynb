np.float32)


inputs = Input(shape=(30,))

layer_1 = Dense(15, activation='relu')
layer_1_output = layer_1(inputs)

layer_2 = Dense(15, activation='relu')
layer_2_output = layer_2(layer_1_output)

transpose_layer = Dense(30, activation='relu', use_bias=False)
transpose_layer_output = transpose_layer(layer_2_output)

transpose_layer.set_weights([layer_1.get_weights()[0].T])

model_link1_locn1 = Model(inputs=inputs, outputs=transpose_layer_output)
model_link1_locn1.compile('adam', loss='categorical_crossentropy')
model_link1_locn1.summary()

history_link1_locn1 = model_link1_locn1.fit(inp_link1_locn1, inp_link1_locn1,steps_per_epoch=5, epochs=10, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_51 (InputLayer)        (None, 30)                0
# _________________________________________________________________
# dense_148 (Dense)            (None, 15)                465
# _________________________________________________________________
# dense_149 (Dense)            (None, 15)                240
# _________________________________________________________________
# dense_150 (Dense)            (None, 30)                450
# =================================================================
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 1s - loss: 5841.6350
# Epoch 2/10
#  - 0s - loss: 5744.5182
# Epoch 3/10
#  - 0s - loss: 5723.0312
# Epoch 4/10
#  - 0s - loss: 5708.8741
# Epoch 5/10
#  - 0s - loss: 5699.5343
# Epoch 6/10
#  - 0s - loss: 5692.9462
# Epoch 7/10
#  - 0s - loss: 5687.9367
# Epoch 8/10
#  - 0s - loss: 5683.9437
# Epoch 9/10
#  - 0s - loss: 5680.6520
# Epoch 10/10
#  - 0s - loss: 5677.8754

# %%
# Link-2 Location-1 Autoencoder

inp_link2_locn1=data.values[:30,2]
inp_link2_locn1=inp_link2_locn1.reshape(1,-1)
#print(inp.shape)
inp_link2_locn1 = tf.convert_to_tensor(inp_link2_locn1, np.float32)


inputs = Input(shape=(30,))

layer_1 = Dense(15, activation='relu')
layer_1_output = layer_1(inputs)

layer_2 = Dense(15, activation='relu')
layer_2_output = layer_2(layer_1_output)

transpose_layer = Dense(30, activation='relu', use_bias=False)
transpose_layer_output = transpose_layer(layer_2_output)

transpose_layer.set_weights([layer_1.get_weights()[0].T])

model_link2_locn1 = Model(inputs=inputs, outputs=transpose_layer_output)
model_link2_locn1.compile('adam', loss='categorical_crossentropy')
model_link2_locn1.summary()

history_link2_locn1 = model_link2_locn1.fit(inp_link2_locn1, inp_link2_locn1,steps_per_epoch=5, epochs=10, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_52 (InputLayer)        (None, 30)                0
# _________________________________________________________________
# dense_151 (Dense)            (None, 15)                465
# _________________________________________________________________
# dense_152 (Dense)            (None, 15)                240
# _________________________________________________________________
# dense_153 (Dense)            (None, 30)                450
# =================================================================
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 0s - loss: 2886.5425
# Epoch 2/10
#  - 0s - loss: 2865.9663
# Epoch 3/10
#  - 0s - loss: 2859.8473
# Epoch 4/10
#  - 0s - loss: 2856.1970
# Epoch 5/10
#  - 0s - loss: 2853.6945
# Epoch 6/10
#  - 0s - loss: 2851.8631
# Epoch 7/10
#  - 0s - loss: 2850.4864
# Epoch 8/10
#  - 0s - loss: 2849.4512
# Epoch 9/10
#  - 0s - loss: 2848.6699
# Epoch 10/10
#  - 0s - loss: 2848.0702

# %%
# Link-3 Location-1 Autoencoder

inp_link3_locn1=data.values[:30,3]
inp_link3_locn1=inp_link3_locn1.reshape(1,-1)
#print(inp.shape)
inp_link3_locn1 = tf.convert_to_tensor(inp_link3_locn1, np.float32)


inputs = Input(shape=(30,))

layer_1 = Dense(15, activation='relu')
layer_1_output = layer_1(inputs)

layer_2 = Dense(15, activation='relu')
layer_2_output = layer_2(layer_1_output)

transpose_layer = Dense(30, activation='relu', use_bias=False)
transpose_layer_output = transpose_layer(layer_2_output)

transpose_layer.set_weights([layer_1.get_weights()[0].T])

model_link3_locn1 = Model(inputs=inputs, outputs=transpose_layer_output)
model_link3_locn1.compile('adam', loss='categorical_crossentropy')
model_link3_locn1.summary()

history_link3_locn1 = model_link3_locn1.fit(inp_link3_locn1, inp_link3_locn1,steps_per_epoch=5, epochs=10, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_53 (InputLayer)        (None, 30)                0
# _________________________________________________________________
# dense_154 (Dense)            (None, 15)                465
# _________________________________________________________________
# dense_155 (Dense)            (None, 15)                240
# _________________________________________________________________
# dense_156 (Dense)            (None, 30)                450
# =================================================================
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 1s - loss: 7747.4449
# Epoch 2/10
#  - 0s - loss: 7374.4255
# Epoch 3/10
#  - 0s - loss: 7001.7463
# Epoch 4/10
#  - 0s - loss: 6901.2981
# Epoch 5/10
#  - 0s - loss: 6881.1908
# Epoch 6/10
#  - 0s - loss: 6854.5190
# Epoch 7/10
#  - 0s - loss: 6837.9523
# Epoch 8/10
#  - 0s - loss: 6828.4800
# Epoch 9/10
#  - 0s - loss: 6822.1591
# Epoch 10/10
#  - 0s - loss: 6816.9691

# %%
# Link-4 Location-1 Autoencoder

inp_link4_locn1=data.values[:30,4]
inp_link4_locn1=inp_link4_locn1.reshape(1,-1)
#print(inp.shape)
inp_link4_locn1 = tf.convert_to_tensor(inp_link4_locn1, np.float32)


inputs = Input(shape=(30,))

layer_1 = Dense(15, activation='relu')
layer_1_output = layer_1(inputs)

layer_2 = Dense(15, activation='relu')
layer_2_output = layer_2(layer_1_output)

transpose_layer = Dense(30, activation='relu', use_bias=False)
transpose_layer_output = transpose_layer(layer_2_output)

transpose_layer.set_weights([layer_1.get_weights()[0].T])

model_link4_locn1 = Model(inputs=inputs, outputs=transpose_layer_output)
model_link4_locn1.compile('adam', loss='categorical_crossentropy')
model_link4_locn1.summary()

history_link4_locn1 = model_link4_locn1.fit(inp_link4_locn1, inp_link4_locn1,steps_per_epoch=5, epochs=10, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_54 (InputLayer)        (None, 30)                0
# _________________________________________________________________
# dense_157 (Dense)            (None, 15)                465
# _________________________________________________________________
# dense_158 (Dense)            (None, 15)                240
# _________________________________________________________________
# dense_159 (Dense)            (None, 30)                450
# =================================================================
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 1s - loss: 4224.3282
# Epoch 2/10
#  - 0s - loss: 3968.8352
# Epoch 3/10
#  - 0s - loss: 3948.2258
# Epoch 4/10
#  - 0s - loss: 3930.0774
# Epoch 5/10
#  - 0s - loss: 3920.5078
# Epoch 6/10
#  - 0s - loss: 3913.6909
# Epoch 7/10
#  - 0s - loss: 3866.1639
# Epoch 8/10
#  - 0s - loss: 3774.4694
# Epoch 9/10
#  - 0s - loss: 3753.1855
# Epoch 10/10
#  - 0s - loss: 3587.1423

# %%
# Link-1 Location-2 Autoencoder

inp_link1_locn2=data.values[:30,1]
inp_link1_locn2=inp_link1_locn2.reshape(1,-1)
#print(inp.shape)
inp_link1_locn2 = tf.convert_to_tensor(inp_link1_locn2, np.float32)


inputs = Input(shape=(30,))

layer_1 = Dense(15, activation='relu')
layer_1_output = layer_1(inputs)

layer_2 = Dense(15, activation='relu')
layer_2_output = layer_2(layer_1_output)

transpose_layer = Dense(30, activation='relu', use_bias=False)
transpose_layer_output = transpose_layer(layer_2_output)

transpose_layer.set_weights([layer_1.get_weights()[0].T])

model_link1_locn2 = Model(inputs=inputs, outputs=transpose_layer_output)
model_link1_locn2.compile('adam', loss='categorical_crossentropy')
model_link1_locn2.summary()

history_link1_locn2 = model_link2_locn1.fit(inp_link2_locn1, inp_link2_locn1,steps_per_epoch=5, epochs=10, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_55 (InputLayer)        (None, 30)                0
# _________________________________________________________________
# dense_160 (Dense)            (None, 15)                465
# _________________________________________________________________
# dense_161 (Dense)            (None, 15)                240
# _________________________________________________________________
# dense_162 (Dense)            (None, 30)                450
# =================================================================
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 0s - loss: 2847.5912
# Epoch 2/10
#  - 0s - loss: 2847.1958
# Epoch 3/10
#  - 0s - loss: 2846.8578
# Epoch 4/10
#  - 0s - loss: 2846.5590
# Epoch 5/10
#  - 0s - loss: 2846.2887
# Epoch 6/10
#  - 0s - loss: 2846.0410
# Epoch 7/10
#  - 0s - loss: 2845.8128
# Epoch 8/10
#  - 0s - loss: 2845.6019
# Epoch 9/10
#  - 0s - loss: 2845.4074
# Epoch 10/10
#  - 0s - loss: 2845.2280

# %%
# Link-2 Location-2 Autoencoder

inp_link2_locn2=data.values[:30,2]
inp_link2_locn2=inp_link2_locn2.reshape(1,-1)
#print(inp.shape)
inp_link2_locn2 = tf.convert_to_tensor(inp_link2_locn2, np.float32)


inputs = Input(shape=(30,))

layer_1 = Dense(15, activation='relu')
layer_1_output = layer_1(inputs)

layer_2 = Dense(15, activation='relu')
layer_2_output = layer_2(layer_1_output)

transpose_layer = Dense(30, activation='relu', use_bias=False)
transpose_layer_output = transpose_layer(layer_2_output)

transpose_layer.set_weights([layer_1.get_weights()[0].T])

model_link2_locn2 = Model(inputs=inputs, outputs=transpose_layer_output)
model_link2_locn2.compile('adam', loss='categorical_crossentropy')
model_link2_locn2.summary()

history_link2_locn2 = model_link2_locn2.fit(inp_link2_locn2, inp_link2_locn2,steps_per_epoch=5, epochs=10, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_56 (InputLayer)        (None, 30)                0
# _________________________________________________________________
# dense_163 (Dense)            (None, 15)                465
# _________________________________________________________________
# dense_164 (Dense)            (None, 15)                240
# _________________________________________________________________
# dense_165 (Dense)            (None, 30)                450
# =================================================================
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 1s - loss: 2616.6958
# Epoch 2/10
#  - 0s - loss: 2600.5589
# Epoch 3/10
#  - 0s - loss: 2594.6545
# Epoch 4/10
#  - 0s - loss: 2571.4198
# Epoch 5/10
#  - 0s - loss: 2357.7984
# Epoch 6/10
#  - 0s - loss: 2334.6339
# Epoch 7/10
#  - 0s - loss: 2328.6029
# Epoch 8/10
#  - 0s - loss: 2323.3257
# Epoch 9/10
#  - 0s - loss: 2319.0275
# Epoch 10/10
#  - 0s - loss: 2315.9188

# %%
# Link-3 Location-1 Autoencoder

inp_link3_locn2=data.values[:30,3]
inp_link3_locn2=inp_link3_locn2.reshape(1,-1)
#print(inp.shape)
inp_link3_locn2 = tf.convert_to_tensor(inp_link3_locn2, np.float32)


inputs = Input(shape=(30,))

layer_1 = Dense(15, activation='relu')
layer_1_output = layer_1(inputs)

layer_2 = Dense(15, activation='relu')
layer_2_output = layer_2(layer_1_output)

transpose_layer = Dense(30, activation='relu', use_bias=False)
transpose_layer_output = transpose_layer(layer_2_output)

transpose_layer.set_weights([layer_1.get_weights()[0].T])

model_link3_locn2 = Model(inputs=inputs, outputs=transpose_layer_output)
model_link3_locn2.compile('adam', loss='categorical_crossentropy')
model_link3_locn2.summary()

history_link3_locn2 = model_link3_locn2.fit(inp_link3_locn2, inp_link3_locn2,steps_per_epoch=5, epochs=10, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_57 (InputLayer)        (None, 30)                0
# _________________________________________________________________
# dense_166 (Dense)            (None, 15)                465
# _________________________________________________________________
# dense_167 (Dense)            (None, 15)                240
# _________________________________________________________________
# dense_168 (Dense)            (None, 30)                450
# =================================================================
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 1s - loss: 7099.5760
# Epoch 2/10
#  - 0s - loss: 6992.2147
# Epoch 3/10
#  - 0s - loss: 6698.3689
# Epoch 4/10
#  - 0s - loss: 6404.0439
# Epoch 5/10
#  - 0s - loss: 6284.4339
# Epoch 6/10
#  - 0s - loss: 6278.1527
# Epoch 7/10
#  - 0s - loss: 6046.0634
# Epoch 8/10
#  - 0s - loss: 6004.4772
# Epoch 9/10
#  - 0s - loss: 5991.6441
# Epoch 10/10
#  - 0s - loss: 5984.1190

# %%
# Link-4 Location-1 Autoencoder

inp_link4_locn2=data.values[:30,4]
inp_link4_locn2=inp_link4_locn2.reshape(1,-1)
#print(inp.shape)
inp_link4_locn2 = tf.convert_to_tensor(inp_link4_locn2, np.float32)


inputs = Input(shape=(30,))

layer_1 = Dense(15, activation='relu')
layer_1_output = layer_1(inputs)

layer_2 = Dense(15, activation='relu')
layer_2_output = layer_2(layer_1_output)

transpose_layer = Dense(30, activation='relu', use_bias=False)
transpose_layer_output = transpose_layer(layer_2_output)

transpose_layer.set_weights([layer_1.get_weights()[0].T])

model_link4_locn2 = Model(inputs=inputs, outputs=transpose_layer_output)
model_link4_locn2.compile('adam', loss='categorical_crossentropy')
model_link4_locn2.summary()

history_link4_locn2 = model_link4_locn2.fit(inp_link4_locn2, inp_link4_locn2,steps_per_epoch=5, epochs=10, verbose=2)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_58 (InputLayer)        (None, 30)                0
# _________________________________________________________________
# dense_169 (Dense)            (None, 15)                465
# _________________________________________________________________
# dense_170 (Dense)            (None, 15)                240
# _________________________________________________________________
# dense_171 (Dense)            (None, 30)                450
# =================================================================
# Total params: 1,155
# Trainable params: 1,155
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
#  - 1s - loss: 5627.0748
# Epoch 2/10
#  - 0s - loss: 5611.0432
# Epoch 3/10
#  - 0s - loss: 5602.1620
# Epoch 4/10
#  - 0s - loss: 5596.2133
# Epoch 5/10
#  - 0s - loss: 5591.4190
# Epoch 6/10
#  - 0s - loss: 5587.5674
# Epoch 7/10
#  - 0s - loss: 5584.3155
# Epoch 8/10
#  - 0s - loss: 5581.5769
# Epoch 9/10
#  - 0s - loss: 5579.2635
# Epoch 10/10
#  - 0s - loss: 5577.2981
